# %%
# !wget <link>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('diabetes_data_upload.csv')

# %%
df.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %% [markdown]
# ## To check any other class is present

# %%
for column in df.columns[2:-1]:
    if np.in1d(df[column].unique(), ['Yes', 'No']).all():
        print('{}: Okay'.format(column))
    else:
        print('{}: Check Classes'.format(column))
# Out:
# Polyuria: Okay
# Polydipsia: Okay
# sudden weight loss: Okay
# weakness: Okay
# Polyphagia: Okay
# Genital thrush: Okay
# visual blurring: Okay
# Itching: Okay
# Irritability: Okay
# delayed healing: Okay
# partial paresis: Okay
# muscle stiffness: Okay
# Alopecia: Okay
# Obesity: Okay
